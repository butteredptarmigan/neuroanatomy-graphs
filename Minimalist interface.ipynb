# %%
from pyvis.network import Network

# %%
# %%capture
net = Network(directed=True, notebook=True)

# %%
from widgets import add_node_box, add_edge_box

# %%
add_node_box(net)
# Out:
# Box(children=(Label(value='Struktura'), Text(value='', placeholder='nazwa'), Text(value='', placeholder='skrót…

# %%
add_edge_box(net)
# Out:
# Box(children=(Box(children=(Text(value='', placeholder='A'), Label(value=' → '), Text(value='', placeholder='B…

# %%
net.show('networks/minimalist.html')
# Out:
# networks/minimalist.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="networks/minimalist.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
