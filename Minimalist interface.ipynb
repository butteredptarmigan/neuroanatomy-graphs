# %%
from pyvis.network import Network

# %%
# %%capture
net = Network(directed=True, notebook=True)

# %%
import ipywidgets
from widgets import add_node_box, add_edge_box, refresh_output_factory

# %%
out = ipywidgets.Output()
out_file = 'networks/minimalist.html'
callback = refresh_output_factory(net, out, out_file)

# %%
add_node_box(net, callback)
# Out:
# Box(children=(Label(value='Struktura'), Text(value='', placeholder='nazwa'), Text(value='', placeholder='skrót…

# %%
add_edge_box(net, callback)
# Out:
# Box(children=(Box(children=(Text(value='', placeholder='A'), Label(value=' → '), Text(value='', placeholder='B…

# %%
out
# Out:
# Output()
